# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Importing Dataset

# %%
data = pd.read_csv("https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv")
data
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
data.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
data.tail()
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 57389                 NaN           7.0         NaN                  NaN  ...
# 57390                 NaN           7.0         NaN                  NaN  ...
# 57391                 NaN           7.0         NaN                  NaN  ...
# 57392                 NaN           7.0         NaN                  NaN  ...
# 57393                 NaN           7.0         NaN                  NaN  ...
#
# ...

# %% [markdown]
# # 2. High Level Data Understanding

# %% [markdown]
# # a. Find number of rows and columns in dataset

# %%
print("Number of columns in the dataset:",len(data.columns))
# Out:
# Number of columns in the dataset: 49

# %%
print("Number of rows in the dataset:",len(data.index))
# Out:
# Number of rows in the dataset: 57394

# %% [markdown]
# # b. Datatypes of columns

# %%
d = data.dtypes
print("Data types of columns are as follows:\n\n", d)
# Out:
# Data types of columns are as follows:
#
#  iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# ...

# %% [markdown]
# # c. Info and describe of data in dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %% [markdown]
# # 3. Low Level Data Understanding

# %% [markdown]
# # a. Find count of unique values in location column

# %%
print("Count of unique values in location column is: ",len(data['location'].unique()))
# Out:
# Count of unique values in location column is:  216

# %% [markdown]
# # b. Find which continent has maximum frequency using values count

# %%
print("Continent with maximum frequency is: ",data['continent'].value_counts().idxmax())
# Out:
# Continent with maximum frequency is:  Europe

# %% [markdown]
# # c. Find maximum and mean value in 'total_cases'

# %%
print("Maximum value in 'total_cases' is: ",data['total_cases'].max())
# Out:
# Maximum value in 'total_cases' is:  55154651.0

# %%
print("Mean value in 'total_cases' is: ",data['total_cases'].mean())
# Out:
# Mean value in 'total_cases' is:  167797.3688753302

# %% [markdown]
# # d. Find 25%, 50% and 75% quartile value in 'total_deaths'

# %%
data['total_deaths'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     13.0
# 0.50     84.0
# 0.75    727.0
# Name: total_deaths, dtype: float64

# %% [markdown]
# # e. Find which continent has maximum 'human_development_index'

# %%
print("Continent that has maximum 'human_development_index' is: ",data.groupby('continent')['human_development_index'].max().idxmax())
# Out:
# Continent that has maximum 'human_development_index' is:  Europe

# %% [markdown]
# # f. Find which continent has minimum 'gdp_per_capita'

# %%
print("Continent that has maximum 'human_development_index' is: ",data.groupby('continent')['human_development_index'].min().idxmin())
# Out:
# Continent that has maximum 'human_development_index' is:  Africa

# %% [markdown]
# # 4. Filter the dataframe with only this columns

# %%
df_1 = data[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]
df_1
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # 5. Data Cleaning

# %% [markdown]
# # a. Remove all duplicate observations

# %%
df_1.drop_duplicates()
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # b. Find missing values in all columns

# %%
df_1.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %% [markdown]
# # c. Remove all observations where continent column value is missing

# %%
df_1['continent'].dropna(axis = 0, how = 'any')
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4          Asia
#           ...
# 56743    Africa
# 56744    Africa
# 56745    Africa
# 56746    Africa
# 56747    Africa
# Name: continent, Length: 56748, dtype: object

# %% [markdown]
# # d. Fill all missing values with 0

# %%
df_1 = df.fillna(0)
df_1
# Out:
#       continent       location       date  total_cases  total_deaths  \
# 0          Asia    Afghanistan 2019-12-31          0.0           0.0
# 1          Asia    Afghanistan 2020-01-01          0.0           0.0
# 2          Asia    Afghanistan 2020-02-01          0.0           0.0
# 3          Asia    Afghanistan 2020-03-01          0.0           0.0
# 4          Asia    Afghanistan 2020-04-01          0.0           0.0
# ...         ...            ...        ...          ...           ...
# 57389         0  International 2020-11-13        696.0           7.0
# 57390         0  International 2020-11-14        696.0           7.0
# 57391         0  International 2020-11-15        696.0           7.0
# 57392         0  International 2020-11-16        696.0           7.0
# 57393         0  International 2020-11-17        696.0           7.0
#
#        gdp_per_capita  human_development_index  month
# 0            1803.987                    0.498     12
# ...

# %% [markdown]
# # 6. Data Time Format

# %% [markdown]
# # a. Convert date column in datetime format using pandas.to_datetime

# %%
df_1['date'] = pd.to_datetime(df_1['date'])
df_1['date']
# Out:
# 0       2019-12-31
# 1       2020-01-01
# 2       2020-02-01
# 3       2020-03-01
# 4       2020-04-01
#            ...
# 57389   2020-11-13
# 57390   2020-11-14
# 57391   2020-11-15
# 57392   2020-11-16
# 57393   2020-11-17
# Name: date, Length: 57394, dtype: datetime64[ns]

# %% [markdown]
# # b. Create new column month after extracting month data from date column.

# %%
df_1['month'] = pd.DatetimeIndex(df_1['date']).month
df_1['month']
# Out:
# 0        12
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 57389    11
# 57390    11
# 57391    11
# 57392    11
# 57393    11
# Name: month, Length: 57394, dtype: int64

# %% [markdown]
# # 7. Data Aggregation

# %% [markdown]
# # a. Find max value in all columns using groupby function on 'continent'

# %%
 df_1.groupby(['continent']).max().reset_index()
# Out:
#        continent                      location       date  total_cases  \
# 0              0                         World 2020-12-11   55154651.0
# 1         Africa                      Zimbabwe 2020-12-11     752269.0
# 2           Asia                         Yemen 2020-12-11    8874290.0
# 3         Europe                       Vatican 2020-12-11    1991233.0
# 4  North America  United States Virgin Islands 2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 6  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0     1328537.0       15469.207                    0.000     12
# 1       20314.0       26382.287                    0.797     12
# 2      130519.0      116935.600                    0.933     12
# 3       52147.0       94277.965                    0.953     12
# 4      247220.0       54225.446                    0.926     12
# ...

# %% [markdown]
# # b. Store the result in a new dataframe named 'df_groupby'

# %%
df_groupby = df_1.groupby(['continent']).max().reset_index()
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0              0                         World 2020-12-11   55154651.0
# 1         Africa                      Zimbabwe 2020-12-11     752269.0
# 2           Asia                         Yemen 2020-12-11    8874290.0
# 3         Europe                       Vatican 2020-12-11    1991233.0
# 4  North America  United States Virgin Islands 2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 6  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0     1328537.0       15469.207                    0.000     12
# 1       20314.0       26382.287                    0.797     12
# 2      130519.0      116935.600                    0.933     12
# 3       52147.0       94277.965                    0.953     12
# 4      247220.0       54225.446                    0.926     12
# ...

# %% [markdown]
# # 8. Feature Engineering

# %% [markdown]
# # a. Create a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'

# %%
total_deaths_to_total_cases = df_1['total_deaths']/df_1['total_cases']
total_deaths_to_total_cases
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 57389    0.010057
# 57390    0.010057
# 57391    0.010057
# 57392    0.010057
# 57393    0.010057
# Length: 57394, dtype: float64

# %% [markdown]
# # 9. Data Visualization

# %% [markdown]
# # a. Perform Univariate Analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot

# %%
sns.distplot(df_1['gdp_per_capita'],bins = 20, kde = True)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# # b. Plot a scatter plot of 'total_cases' and 'gdp_per_capita'

# %%
plt.scatter(df_groupby['gdp_per_capita'], df_groupby['total_cases'])
plt.ylabel('total_cases')
plt.xlabel('gdp_per_capita')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %% [markdown]
# # c. Plot pairplot on df_groupby dataset

# %%
sns.pairplot(df_groupby)

# %% [markdown]
# # d. Plot a bar plot of 'continent' column with 'total_cases'

# %%
sns.barplot(x = 'continent', y ='total_cases', data = df_groupby, hue = 'continent')
# Out:
# <AxesSubplot:xlabel='continent', ylabel='total_cases'>

# %% [markdown]
# # 10. Save the df_groupby dataframe in your local drive using pandas.to_csv function

# %%
from pathlib import Path
filepath = Path('Data Wrangling.csv')
filepath.parent.mkdir(parents = True, exist_ok = True)
df_groupby.to_csv(filepath)
